# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Fortune500.csv")

# %% [markdown]
# # Data Cleaning

# %%
df["Rank"] = df["Rank"].astype(int)

# %%
df["Revenue"] = (df["Revenue"].astype(str).str.replace("$", "").str.replace(",", ""))
df["Revenue"] = pd.to_numeric(df["Revenue"])

# %%
df["Profit"] = (df["Profit"].astype(str).str.replace("$", "").str.replace(",", ""))
df["Profit"] = pd.to_numeric(df["Profit"])

# %%
df["Assets"] = (df["Assets"].astype(str).str.replace("$", "").str.replace(",", ""))
df["Assets"] = pd.to_numeric(df["Assets"])

# %%
df["Employees"] = (df["Employees"].astype(str).str.replace(",", ""))
df["Employees"] = pd.to_numeric(df["Employees"]).astype("Int64")

# %%
df["Growth"] = (df["Growth"].astype(str).str.replace("%", "").replace("nan", np.nan))
df["Growth"] = pd.to_numeric(df["Growth"].astype(float))

# %%
df["Profit_Margin"] = (df["Profit_Margin"].astype(str).str.replace("%","").str.replace(",",""))

# %%
df["Profit_Margin"] = pd.to_numeric(df["Profit_Margin"].astype(float))

# %%
df["Years"] = pd.to_numeric(df["Years"]).astype("Int64")

# %%
df
# Out:
#      Rank                   Company   Revenue  Growth    Profit  \
# 0       1                   Walmart  680985.0     5.1   19436.0
# 1       2                    Amazon  637959.0    11.0   59248.0
# 2       3                State Grid  548414.4     0.5   10044.9
# 3       4              Saudi Aramco  480193.5    -3.0  104982.3
# 4       5  China National Petroleum  412645.3    -2.2   22424.0
# ..    ...                       ...       ...     ...       ...
# 495   496                   Wistron   32687.7    17.4     543.5
# 496   497                 Medtronic   32364.0     3.6    3676.0
# 497   498  New China Life Insurance   32293.1    15.5   -1438.2
# 498   499  China General Technology   32282.4    11.6    -150.6
# 499   500                  Heineken   32249.4    -1.8     538.6
#
#      Profit_Margin    Assets  Employees Change  Years
# 0             25.3  260823.0    2100000      -     31
# 1             94.7  624894.0    1556000      -     17
# 2              9.1  797694.0    1354310      -     25
# 3            -13.0  645097.2      75118      -      7
# 4              5.3  607615.1     985155      1     25
# ..             ...       ...        ...    ...    ...
# 495           47.5   17985.7      42091      -      9
# 496           -2.2   89981.0      95000      -      8
# 497            NaN  231852.4      28675      -      6
# 498         -148.6   44268.6     102874      -      8
# 499          -57.6   55368.6      88497    -13     16
#
# [500 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           500 non-null    int32
#  1   Company        500 non-null    object
#  2   Revenue        500 non-null    float64
#  3   Growth         496 non-null    float64
#  4   Profit         500 non-null    float64
#  5   Profit_Margin  466 non-null    float64
#  6   Assets         500 non-null    float64
#  7   Employees      500 non-null    Int64
#  8   Change         500 non-null    object
#  9   Years          500 non-null    Int64
# dtypes: Int64(2), float64(5), int32(1), object(2)
# memory usage: 38.2+ KB

# %%
df.head()
# Out:
#    Rank                   Company   Revenue  Growth    Profit  Profit_Margin  \
# 0     1                   Walmart  680985.0     5.1   19436.0           25.3
# 1     2                    Amazon  637959.0    11.0   59248.0           94.7
# 2     3                State Grid  548414.4     0.5   10044.9            9.1
# 3     4              Saudi Aramco  480193.5    -3.0  104982.3          -13.0
# 4     5  China National Petroleum  412645.3    -2.2   22424.0            5.3
#
#      Assets  Employees Change  Years
# 0  260823.0    2100000      -     31
# 1  624894.0    1556000      -     17
# 2  797694.0    1354310      -     25
# 3  645097.2      75118      -      7
# 4  607615.1     985155      1     25

# %%
df.tail()
# Out:
#      Rank                   Company  Revenue  Growth  Profit  Profit_Margin  \
# 495   496                   Wistron  32687.7    17.4   543.5           47.5
# 496   497                 Medtronic  32364.0     3.6  3676.0           -2.2
# 497   498  New China Life Insurance  32293.1    15.5 -1438.2            NaN
# 498   499  China General Technology  32282.4    11.6  -150.6         -148.6
# 499   500                  Heineken  32249.4    -1.8   538.6          -57.6
#
#        Assets  Employees Change  Years
# 495   17985.7      42091      -      9
# 496   89981.0      95000      -      8
# 497  231852.4      28675      -      6
# 498   44268.6     102874      -      8
# 499   55368.6      88497    -13     16

# %%
df.describe()
# Out:
#              Rank        Revenue      Growth         Profit  Profit_Margin  \
# count  500.000000     500.000000  496.000000     500.000000     466.000000
# mean   250.500000   83465.356800    3.493145    5954.176600       7.006438
# std    144.481833   78574.964811   13.284238   12542.135021     609.692037
# min      1.000000   32249.400000  -43.100000  -42633.400000   -9427.000000
# 25%    125.750000   41577.125000   -2.925000     835.700000     -25.525000
# 50%    250.500000   56190.100000    2.250000    3297.150000       0.950000
# 75%    375.250000   90263.400000    8.100000    6303.175000      18.975000
# max    500.000000  680985.000000  114.200000  104982.300000    7332.600000
#
#              Assets      Employees      Years
# count  5.000000e+02          500.0      500.0
# mean   3.425871e+05     140290.076     19.438
# std    7.352501e+05  180044.285171  10.351447
# min    6.731800e+03         3201.0        1.0
# 25%    5.113588e+04       47590.25       10.0
# 50%    1.016076e+05        92917.0       20.0
# 75%    2.721943e+05       169398.5       31.0
# max    6.688552e+06      2100000.0       31.0

# %%
df.max()
# Out:
# Rank                                500
# Company          Zurich Insurance Group
# Revenue                        680985.0
# Growth                            114.2
# Profit                         104982.3
# Profit_Margin                    7332.6
# Assets                        6688551.8
# Employees                       2100000
# Change                               96
# Years                                31
# dtype: object

# %%
df.value_counts()
# Out:
# Rank  Company                       Revenue   Growth  Profit   Profit_Margin  Assets    Employees  Change  Years
# 1     Walmart                       680985.0   5.1    19436.0   25.3          260823.0  2100000    -       31       1
# 338   Susun Construction Group      45003.8   -0.6    924.2    -19.1          34018.5   122635     2       4        1
# 336   Eli Lilly                     45042.7    32.0   10590.0   102.1         78714.9   47000      119     17       1
# 335   Ingka Group                   45215.7   -3.7    870.9    -45.5          63700.5   162293     -13     5        1
# 334   Taikang Insurance Group       45456.0    15.3   2115.6    18.5          291482.9  54060      47      8        1
#                                                                                                                    ..
# 158   Sysco                         78844.0    3.3    1955.0    10.4          24917.0   76000      5       31       1
# 156   Engie                         79822.7   -10.6   4440.4    86.0          196256.0  94017      -26     30       1
# 155   Zhejiang Geely Holding Group  79890.6    13.6   835.1     2.8           99153.2   142465     30      14       1
# 154   Albertsons                    80390.9    1.5    958.6    -26.0          26755.7   196650     -2      21       1
# 500   Heineken                      32249.4   -1.8    538.6    -57.6          55368.6   88497      -13     16       1
# Name: count, Length: 463, dtype: int64

# %%
df.isnull()
# Out:
#       Rank  Company  Revenue  Growth  Profit  Profit_Margin  Assets  \
# 0    False    False    False   False   False          False   False
# 1    False    False    False   False   False          False   False
# 2    False    False    False   False   False          False   False
# 3    False    False    False   False   False          False   False
# 4    False    False    False   False   False          False   False
# ..     ...      ...      ...     ...     ...            ...     ...
# 495  False    False    False   False   False          False   False
# 496  False    False    False   False   False          False   False
# 497  False    False    False   False   False           True   False
# 498  False    False    False   False   False          False   False
# 499  False    False    False   False   False          False   False
#
#      Employees  Change  Years
# 0        False   False  False
# 1        False   False  False
# 2        False   False  False
# 3        False   False  False
# 4        False   False  False
# ..         ...     ...    ...
# 495      False   False  False
# 496      False   False  False
# 497      False   False  False
# 498      False   False  False
# 499      False   False  False
#
# [500 rows x 10 columns]

# %%
df
# Out:
#      Rank                   Company   Revenue  Growth    Profit  \
# 0       1                   Walmart  680985.0     5.1   19436.0
# 1       2                    Amazon  637959.0    11.0   59248.0
# 2       3                State Grid  548414.4     0.5   10044.9
# 3       4              Saudi Aramco  480193.5    -3.0  104982.3
# 4       5  China National Petroleum  412645.3    -2.2   22424.0
# ..    ...                       ...       ...     ...       ...
# 495   496                   Wistron   32687.7    17.4     543.5
# 496   497                 Medtronic   32364.0     3.6    3676.0
# 497   498  New China Life Insurance   32293.1    15.5   -1438.2
# 498   499  China General Technology   32282.4    11.6    -150.6
# 499   500                  Heineken   32249.4    -1.8     538.6
#
#      Profit_Margin    Assets  Employees Change  Years
# 0             25.3  260823.0    2100000      -     31
# 1             94.7  624894.0    1556000      -     17
# 2              9.1  797694.0    1354310      -     25
# 3            -13.0  645097.2      75118      -      7
# 4              5.3  607615.1     985155      1     25
# ..             ...       ...        ...    ...    ...
# 495           47.5   17985.7      42091      -      9
# 496           -2.2   89981.0      95000      -      8
# 497            NaN  231852.4      28675      -      6
# 498         -148.6   44268.6     102874      -      8
# 499          -57.6   55368.6      88497    -13     16
#
# [500 rows x 10 columns]

# %%
df.to_csv("Fortune500_cleaned.csv",index=False)

# %% [markdown]
# # Univariante analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Revenue
plt.figure(figsize=(10,5))
sns.histplot(df["Revenue"].head(10), bins=10, kde=True)
plt.title("Distribution of Revenue")
plt.xlabel("Revenue (in Millions)")
plt.show()

# %%
# Profit
plt.figure(figsize=(8,5))
sns.boxplot(y=df["Profit"].head(10))
plt.title("Boxplot of Profit (Outlier Detection)")
plt.show()

# %%
# Employees
plt.figure(figsize=(10,5))
plt.ticklabel_format(style='plain', axis='x')

sns.histplot(df["Employees"].head(10), bins=10, kde=True)
plt.title("Distribution of Employees")
plt.xlabel("Employees")
plt.show()

# %%
# Profit Margin 
plt.figure(figsize=(8,5))
sns.histplot(df["Profit_Margin"].head(10), bins=20, kde=True)
plt.title("Distribution of Profit Margin")
plt.show()

# %% [markdown]
# # Numerical vs Numerical

# %%
# Scatter Plot: Revenue vs Profit
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['Revenue'].head(10), y=df['Profit'])
plt.title('Scatter Plot: Revenue vs Profit')
plt.xlabel('Revenue')
plt.ylabel('Profit')
plt.show()

# %%
# Line Plot: Revenue vs Profit
plt.figure(figsize=(6,4))
sns.lineplot(x=df['Revenue'].head(10), y=df['Profit'])
plt.title('Line Plot: Revenue vs Profit')
plt.xlabel('Revenue')
plt.ylabel('Profit')
plt.show()

# %%
sns.barplot(x=df['Employees'].head(10), y=df['Profit'])
plt.title('Average Profit by Employees')
plt.xlabel('Employees')
plt.xticks(rotation=90)
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# # Numerical vs categorical

# %%
plt.figure(figsize=(11,5))
plt.ticklabel_format(style='plain', axis='y')
sns.barplot(x=df['Company'].head(10), y=df['Employees'])
plt.title('Average Employees by Company')
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Average Employees')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Company'].head(10), y=df['Revenue'])
plt.title('Average Employees by Company')
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Company'].head(), y=df['Rank'])
plt.title('Average Employees by Company')
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Rank')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Company'].head(), y=df['Growth'])
plt.title('Average Employees by Company')
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Growth')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Company'].head(), y=df['Profit'])
plt.title('Average Employees by Company')
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Company'].head(), y=df['Profit_Margin'])
plt.title('Average Employees by Company')
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Profit_Margin')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Company'].head(), y=df['Assets'])
plt.title('Average Employees by Company')
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Assets')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['Company'].head(), y=df['Years'])
plt.title('Average Employees by Company')
plt.xticks(rotation=90)
plt.xlabel('Company')
plt.ylabel('Years')
plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# # 1 High revenue does NOT always mean high profit
#
# In the Fortune 500 list, many companies have:
#
# Very high revenue
#
# But low profit
#
# Because of thin profit margins
#
# Example Insight Statement:
# Some companies generate huge revenue but their profitability is low, indicating high operational costs or low margins.

# %%
high_revenue=df.sort_values('Revenue',ascending=False).head(10)
high_revenue[["Rank",'Company','Revenue','Profit','Profit_Margin']]
# Out:
#    Rank                   Company   Revenue    Profit  Profit_Margin
# 0     1                   Walmart  680985.0   19436.0           25.3
# 1     2                    Amazon  637959.0   59248.0           94.7
# 2     3                State Grid  548414.4   10044.9            9.1
# 3     4              Saudi Aramco  480193.5  104982.3          -13.0
# 4     5  China National Petroleum  412645.3   22424.0            5.3
# 5     6             Sinopec Group  407490.1    8036.4          -14.5
# 6     7        UnitedHealth Group  400278.0   14405.0          -35.6
# 7     8                     Apple  391035.0   93736.0           -3.4
# 8     9                CVS Health  372809.0    4614.0          -44.7
# 9    10        Berkshire Hathaway  371433.0   88995.0           -7.5

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=high_revenue, x="Revenue", y="Profit", s=100,hue='Company')
plt.title("Revenue vs Profit (Top 10 Revenue Companies)")
plt.xlabel("Revenue")
plt.ylabel("Profit")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=high_revenue, x="Company", y="Revenue", color="skyblue", label="Revenue")
sns.barplot(data=high_revenue, x="Company", y="Profit", color="tomato", label="Profit")
plt.xticks(rotation=90)
plt.title("Revenue vs Profit Comparison (Top 10 Companies)")
plt.ylabel("Value")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=high_revenue, x="Company", y="Profit_Margin")
plt.xticks(rotation=90)
plt.title("Profit Margin Among Top 10 Revenue Companies")
plt.ylabel("Profit Margin (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2 Profit Margin tells a different story than Profit
#
# Two companies can have:
#
# Same profit
#
# But completely different efficiency
#
# Example Insight:
#
# Companies with high profit margins are more efficient and earn more money per dollar of revenue, even if their total revenue is lower.

# %%
profit_margin=df.sort_values('Profit_Margin',ascending=False).head(10)
profit_margin[["Rank",'Company','Profit','Profit_Margin']]
# Out:
#      Rank                             Company   Profit  Profit_Margin
# 426   427                   China Electronics   1989.8         7332.6
# 216   217                               Merck  17117.0         4589.6
# 299   300      Liberty Mutual Insurance Group   4383.0         1957.8
# 139   140                                E.ON   4900.0          776.7
# 189   190                                BASF   1403.7          477.1
# 471   472                             Cummins   3946.0          436.9
# 346   347                   Uber Technologies   9856.0          422.3
# 480   481  China National Aviation Fuel Group    381.9          286.8
# 218   219                              Pfizer   8031.0          279.0
# 24     25                     Cardinal Health    852.0          226.4

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(data=profit_margin,x="Profit",y="Profit_Margin",hue="Company",s=120)
plt.title("Profit vs Profit Margin (Top 10 Profit Margin Companies)")
plt.xlabel("Profit")
plt.ylabel("Profit Margin (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3 Revenue is highly correlated with Employees
#
# Large companies hire more people because they operate at massive scale.
#
# - Insight:
#
# Revenue and Employees show a strong positive relationship. Bigger workforces support higher revenue generation.

# %%
revenue=df.sort_values('Employees',ascending=False).head(10)
revenue[["Rank",'Company','Revenue','Employees']]
# Out:
#      Rank                     Company   Revenue  Employees
# 0       1                     Walmart  680985.0    2100000
# 1       2                      Amazon  637959.0    1556000
# 2       3                  State Grid  548414.4    1354310
# 4       5    China National Petroleum  412645.3     985155
# 90     91                         BYD  108003.5     968872
# 210   211                   Accenture   64896.5     774303
# 106   107            China Post Group   97544.4     723227
# 11     12                  Volkswagen  351093.3     646501
# 27     28  Hon Hai Precision Industry  213699.1     633167
# 156   157         U.S. Postal Service   79547.0     586700

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data=revenue, x="Employees", y="Revenue", hue="Company", s=120)
plt.title("Employees vs Revenue (Top 20 Biggest Employers)")
plt.xlabel("Employees")
plt.ylabel("Revenue")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4 Profit correlates strongly with Assets
#
# Companies with more assets (factories, tech, machines, infrastructure) usually produce more profit.
#
# - Insight:
#
# Profit and Assets are highly related, suggesting that companies with a large asset base generate greater income.

# %%
profit=df.sort_values('Profit',ascending=False).head(10)
profit[["Rank",'Company','Profit','Assets','Revenue']]
# Out:
#     Rank                                Company    Profit     Assets   Revenue
# 3      4                           Saudi Aramco  104982.3   645097.2  480193.5
# 12    13                               Alphabet  100118.0   450256.0  350018.0
# 7      8                                  Apple   93736.0   364980.0  391035.0
# 9     10                     Berkshire Hathaway   88995.0  1153881.0  371433.0
# 21    22                              Microsoft   88136.0   512163.0  245122.0
# 65    66                                 Nvidia   72880.0   111601.0  130497.0
# 40    41                         Meta Platforms   62360.0   276054.0  164501.0
# 1      2                                 Amazon   59248.0   624894.0  637959.0
# 18    19                         JPMorgan Chase   58471.0  4002814.0  278906.0
# 25    26  Industrial & Commercial Bank of China   50848.5  6688551.8  221461.3

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=profit, x='Profit', y='Company', palette='viridis')

plt.title("Top 10 Most Profitable Companies")
plt.xlabel("Profit")
plt.ylabel("Company")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4444\193251555.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=profit, x='Profit', y='Company', palette='viridis')

# %% [markdown]
# # 5 Fast growth companies don’t always make high profit
#
# Growth (%) represents change from last year.
#
# - Insight:
#
# High growth companies are not always profitable. Some fast-growing firms may be reinvesting revenue or operating in competitive sectors.

# %%
Rank=df.sort_values('Rank',ascending=True).head(10)
Rank[["Rank",'Company','Profit','Change']]
# Out:
#    Rank                   Company    Profit Change
# 0     1                   Walmart   19436.0      -
# 1     2                    Amazon   59248.0      -
# 2     3                State Grid   10044.9      -
# 3     4              Saudi Aramco  104982.3      -
# 4     5  China National Petroleum   22424.0      1
# 5     6             Sinopec Group    8036.4     -1
# 6     7        UnitedHealth Group   14405.0      1
# 7     8                     Apple   93736.0     -1
# 8     9                CVS Health    4614.0      1
# 9    10        Berkshire Hathaway   88995.0     -1

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=Rank, x='Profit', y='Company', hue='Change', palette='coolwarm')

plt.title("Top 10 Ranked Companies by Profit and Change")
plt.xlabel("Profit")
plt.ylabel("Company")
plt.legend(title="Change")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6 Rank does not perfectly reflect Profit
#
# Rank is based mainly on revenue.
# Profit ranking can be very different.
#
# - Insight:
#
# A company may rank high by revenue but still have relatively low profit, meaning rank alone does not indicate financial strength.

# %%
profit=df.sort_values('Profit',ascending=False).head(10)
profit[["Rank",'Company','Profit']]
# Out:
#     Rank                                Company    Profit
# 3      4                           Saudi Aramco  104982.3
# 12    13                               Alphabet  100118.0
# 7      8                                  Apple   93736.0
# 9     10                     Berkshire Hathaway   88995.0
# 21    22                              Microsoft   88136.0
# 65    66                                 Nvidia   72880.0
# 40    41                         Meta Platforms   62360.0
# 1      2                                 Amazon   59248.0
# 18    19                         JPMorgan Chase   58471.0
# 25    26  Industrial & Commercial Bank of China   50848.5

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=profit, x='Profit', y='Company', palette='viridis')

plt.title("Top 10 Most Profitable Companies")
plt.xlabel("Profit")
plt.ylabel("Company")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4444\193251555.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=profit, x='Profit', y='Company', palette='viridis')

# %% [markdown]
# # 7. Asset-heavy companies tend to have lower Profit Margins
#
# Large asset companies (transport, energy, manufacturing) have:
#
# Higher operating cost
#
# Lower profit margin
#
# - Insight:
#
# Companies with very high assets generally show lower profit margins because of maintenance, production, and logistics costs.

# %%
Asset=df.sort_values('Assets',ascending=False).head(10)
Asset[["Rank",'Company','Profit','Assets']]
# Out:
#     Rank                                Company   Profit     Assets
# 25    26  Industrial & Commercial Bank of China  50848.5  6688551.8
# 29    30             Agricultural Bank of China  39204.6  5923600.2
# 30    31                China Construction Bank  46639.3  5558224.6
# 37    38                          Bank of China  33055.7  4803378.3
# 49    50                             Fannie Mae  16978.0  4349731.0
# 18    19                         JPMorgan Chase  58471.0  4002814.0
# 79    80                            Freddie Mac  11858.0  3386692.0
# 33    34                        Bank of America  27132.0  3261519.0
# 55    56                          HSBC Holdings  23979.0  3017048.0
# 53    54                            BNP Paribas  12639.8  2800691.7

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=Asset, x='Assets', y='Company', palette='plasma')

plt.title("Top 10 Companies by Total Assets")
plt.xlabel("Assets")
plt.ylabel("Company")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4444\860814376.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=Asset, x='Assets', y='Company', palette='plasma')
